# %%
import yaml 

SensorInitialization = {'Fridge1':{'TemperatureAverage':-4 ,'TemperatureVariance':1.5 ,'HumidityAverage':10 ,'HumidityVariance':0.4},
                        'Fridge2':{'TemperatureAverage':-3 ,'TemperatureVariance':1.4 ,'HumidityAverage':12 ,'HumidityVariance':0.5},
                        'Fridge3':{'TemperatureAverage':-2,'TemperatureVariance':1.3 ,'HumidityAverage':14 ,'HumidityVariance':0.6},
                        'Fridge4':{'TemperatureAverage':-1 ,'TemperatureVariance':1.2 ,'HumidityAverage':16 ,'HumidityVariance':0.7},
                        'Fridge5':{'TemperatureAverage':0 ,'TemperatureVariance':1.1 ,'HumidityAverage':18 ,'HumidityVariance':0.8},
                        'Fridge6':{'TemperatureAverage':1 ,'TemperatureVariance':1 ,'HumidityAverage':20 ,'HumidityVariance':0.9},
                        'Fridge7':{'TemperatureAverage':2 ,'TemperatureVariance':0.9 ,'HumidityAverage':22 ,'HumidityVariance':1},
                        'Fridge8':{'TemperatureAverage':3 ,'TemperatureVariance':0.8 ,'HumidityAverage':24 ,'HumidityVariance':1.1},
                        'Fridge9':{'TemperatureAverage':4 ,'TemperatureVariance':0.7 ,'HumidityAverage':26 ,'HumidityVariance':1.2},
                        'Fridge10':{'TemperatureAverage':5 ,'TemperatureVariance':0.6 ,'HumidityAverage':28 ,'HumidityVariance':1.3},
                        'Fridge11':{'TemperatureAverage':0 ,'TemperatureVariance':0.5 ,'HumidityAverage':30 ,'HumidityVariance':1.4},
                        'Fridge12':{'TemperatureAverage':-1 ,'TemperatureVariance':0.4 ,'HumidityAverage':32 ,'HumidityVariance':1.5},
                        'ElectricalSystem':{'VolAverag':220 ,'VolVaridance':4 ,'CurrentAverage':80 ,'CurrentVariance':6 ,'PowerFactorAverage':0.2 , 'PowerFactorVariance':0.1},
                        'EnvironmentalSensors1':{'RoomTempAverage':23 ,'RoomTempVariance':0.5 ,'RoomHumidityAverage':30 ,'RoomHumidityVariance':3},
                        'EnvironmentalSensors2':{'RoomTempAverage':24 ,'RoomTempVariance':1 ,'RoomHumidityAverage':33 ,'RoomHumidityVariance':2},
                        'EnvironmentalSensors3':{'RoomTempAverage':25 ,'RoomTempVariance':1.5 ,'RoomHumidityAverage':36 ,'RoomHumidityVariance':1},
                        'EnvironmentalSensors4':{'RoomTempAverage':26 ,'RoomTempVariance':2 ,'RoomHumidityAverage':39 ,'RoomHumidityVariance':3},
                        'EnvironmentalSensors5':{'RoomTempAverage':27 ,'RoomTempVariance':3 ,'RoomHumidityAverage':42 ,'RoomHumidityVariance':2},
                        'EnvironmentalSensors6':{'RoomTempAverage':25 ,'RoomTempVariance':1.2 ,'RoomHumidityAverage':34 ,'RoomHumidityVariance':1},
                        'EnvironmentalSensors7':{'RoomTempAverage':26 ,'RoomTempVariance':2.1 ,'RoomHumidityAverage':38 ,'RoomHumidityVariance':3},
                        'EnvironmentalSensors8':{'RoomTempAverage':27 ,'RoomTempVariance':2.8 ,'RoomHumidityAverage':40 ,'RoomHumidityVariance':2},
                       }                      
with open('data.yml', 'w') as outfile:
    yaml.dump(SensorInitialization, outfile, default_flow_style=False)   
    
# print(yaml.dump(SensorInitialization))

# %%
print(yaml.dump(SensorInitialization, default_flow_style=False))
# Out:
# ElectricalSystem:
#   CurrentAverage: 80
#   CurrentVariance: 6
#   PowerFactorAverage: 0.2
#   PowerFactorVariance: 0.1
#   VolAverag: 220
#   VolVaridance: 4
# EnvironmentalSensors1:
#   RoomHumidityAverage: 30
#   RoomHumidityVariance: 3
#   RoomTempAverage: 23
#   RoomTempVariance: 0.5
# EnvironmentalSensors2:
#   RoomHumidityAverage: 33
#   RoomHumidityVariance: 2
#   RoomTempAverage: 24
#   RoomTempVariance: 1
# EnvironmentalSensors3:
#   RoomHumidityAverage: 36
#   RoomHumidityVariance: 1
#   RoomTempAverage: 25
#   RoomTempVariance: 1.5
# EnvironmentalSensors4:
#   RoomHumidityAverage: 39
#   RoomHumidityVariance: 3
#   RoomTempAverage: 26
#   RoomTempVariance: 2
# EnvironmentalSensors5:
#   RoomHumidityAverage: 42
#   RoomHumidityVariance: 2
#   RoomTempAverage: 27
#   RoomTempVariance: 3
# EnvironmentalSensors6:
#   RoomHumidityAverage: 34
#   RoomHumidityVariance: 1
#   RoomTempAverage: 25
#   RoomTempVariance: 1.2
# EnvironmentalSensors7:
#   RoomHumidityAverage: 38
# ...
